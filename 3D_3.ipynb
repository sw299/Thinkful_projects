# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import os
import subprocess
import pandas as pd
import csv
from xlrd import open_workbook
from collections import namedtuple
from pprint import pprint
import statistics
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#### Read data columns from the Raw Particle Data file
inputFile1 = "cells_Gmv.00100.vars"
inputFile2 = "cells_Gmv.00150.vars"
inputFile3 = "cells_Gmv.00200.vars"
inputFile4 = "cells_Gmv.00250.vars"
inputFile5 = "cells_Gmv.00300.vars"
inputFile6 = "cells_Gmv.00350.vars"
inputFile7 = "cells_Gmv.00400.vars"
inputFile8 = "cells_Gmv.00450.vars"
inputFile9 = "cells_Gmv.00500.vars"
inputFile10 = "cells_Gmv.00550.vars"
inputFile11= "cells_Gmv.00600.vars"
inputFile12 = "cells_Gmv.00650.vars"
inputFile13 = "cells_Gmv.00700.vars"
inputFile14 = "cells_Gmv.00750.vars"
inputFile15 = "cells_Gmv.00800.vars"
inputFile16 = "cells_Gmv.00850.vars"
inputFile17= "cells_Gmv.00900.vars"
inputFile18 = "cells_Gmv.00950.vars"
inputFile19 = "cells_Gmv.01000.vars"

x1, y1, z1,vol_frac1 = np.genfromtxt(inputFile1,usecols=(1,2,3,5),unpack=True)
x2, y2, z2,vol_frac2 = np.genfromtxt(inputFile2,usecols=(1,2,3,5),unpack=True)
x3, y3, z3,vol_frac3 = np.genfromtxt(inputFile3,usecols=(1,2,3,5),unpack=True)
x4, y4, z4,vol_frac4 = np.genfromtxt(inputFile4,usecols=(1,2,3,5),unpack=True)
x5, y5, z5,vol_frac5 = np.genfromtxt(inputFile5,usecols=(1,2,3,5),unpack=True)
x6, y6, z6,vol_frac6 = np.genfromtxt(inputFile6,usecols=(1,2,3,5),unpack=True)
x7, y7, z7,vol_frac7 = np.genfromtxt(inputFile7,usecols=(1,2,3,5),unpack=True)
x8, y8, z8,vol_frac8 = np.genfromtxt(inputFile8,usecols=(1,2,3,5),unpack=True)
x9, y9, z9,vol_frac9 = np.genfromtxt(inputFile9,usecols=(1,2,3,5),unpack=True)
x10, y10, z10,vol_frac10 = np.genfromtxt(inputFile10,usecols=(1,2,3,5),unpack=True)
x11, y11, z11,vol_frac11 = np.genfromtxt(inputFile11,usecols=(1,2,3,5),unpack=True)
x12, y12, z12,vol_frac12 = np.genfromtxt(inputFile12,usecols=(1,2,3,5),unpack=True)
x13, y13, z13,vol_frac13 = np.genfromtxt(inputFile13,usecols=(1,2,3,5),unpack=True)
x14, y14, z14,vol_frac14 = np.genfromtxt(inputFile14,usecols=(1,2,3,5),unpack=True)
x15, y15, z15,vol_frac15 = np.genfromtxt(inputFile15,usecols=(1,2,3,5),unpack=True)
x16, y16, z16,vol_frac16 = np.genfromtxt(inputFile16,usecols=(1,2,3,5),unpack=True)
x17, y17, z17,vol_frac17 = np.genfromtxt(inputFile17,usecols=(1,2,3,5),unpack=True)
x18, y18, z18,vol_frac18 = np.genfromtxt(inputFile18,usecols=(1,2,3,5),unpack=True)
x19, y19, z19,vol_frac19 = np.genfromtxt(inputFile19,usecols=(1,2,3,5),unpack=True)

# %%
location1 = (z1 == 80)
location2 = (z2 == 80)
location3 = (z3 == 80)
location4 = (z4 == 80)
location5 = (z5 == 80)
location6 = (z6 == 80)
location7 = (z7 == 80)
location8 = (z8 == 80)
location9 = (z9 == 80)
location10 = (z10 == 80)
location11 = (z11 == 80)
location12 = (z12 == 80)
location13 = (z13 == 80)
location14 = (z14 == 80)
location15 = (z15 == 80)
location16 = (z16 == 80)
location17 = (z17 == 80)

X1 = x1[location1]
Y1 = y1[location1]
V1 = vol_frac1[location1]

X2 = x2[location2]
Y2 = y2[location2]
V2 = vol_frac2[location2]

X3 = x3[location3]
Y3 = y3[location3]
V3 = vol_frac3[location3]

X4 = x4[location4]
Y4 = y4[location4]
V4 = vol_frac4[location4]

X5 = x5[location5]
Y5 = y5[location5]
V5 = vol_frac5[location5]

X6 = x6[location6]
Y6 = y6[location6]
V6 = vol_frac6[location6]

X7 = x7[location7]
Y7 = y7[location7]
V7 = vol_frac7[location7]

X8 = x8[location8]
Y8 = y8[location8]
V8 = vol_frac8[location8]

X9 = x9[location9]
Y9 = y9[location9]
V9 = vol_frac9[location9]

X10 = x10[location10]
Y10 = y10[location10]
V10 = vol_frac10[location10]

X11 = x11[location11]
Y11 = y11[location11]
V11 = vol_frac11[location11]

X12 = x12[location12]
Y12 = y12[location12]
V12 = vol_frac12[location12]

X13 = x13[location13]
Y13 = y13[location13]
V13 = vol_frac13[location13]

X14 = x14[location14]
Y14 = y14[location14]
V14 = vol_frac14[location14]

X15 = x15[location15]
Y15 = y15[location15]
V15 = vol_frac15[location15]

X16 = x16[location16]
Y16 = y16[location16]
V16 = vol_frac16[location16]

X17 = x17[location17]
Y17 = y17[location17]
V17 = vol_frac17[location17]

# %%
X_average = (X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10 + X11 + X12 + X13 + X14 + X15 + X16 + X17)/17
Y_average = (Y1 + Y2 + Y3 + Y4 + Y5 + Y6 + Y7 + Y8 + Y9 + Y10 + Y11 + Y12 + Y13 + Y14 + Y15 + Y16 + Y17)/17
V_average = (V1 + V2 + V3 + V4 + V5 + V6 + V7 + V8 + V9 + V10 + V11 + V12 + V13 + V14 + V15 + V16 + V17)/17


# X_average = (X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10 + X11 + X12+ X13)/13
# Y_average = (Y1 + Y2 + Y3 + Y4 + Y5 + Y6 + Y7 + Y8 + Y9 + Y10 + Y11 + Y12+ Y13)/13
# V_average = (V1 + V2 + V3 + V4 + V5 + V6 + V7 + V8 + V9 + V10 + V11 + V12+ V13)/13

# %%
V_average
# Out:
# array([0.26156645, 0.26036317, 0.25977852, ..., 0.27054698, 0.2213663 ,
#        0.15684475])

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d  

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

# ax.plot_trisurf(X1,Y1,V1, linewidth=0.2);
# ax.scatter(X_average,Y_average,V_average,cmap=plt.cm.viridis);

# ax.plot_trisurf(X1,Y1,V1, linewidth=0.2);
# ax.plot_trisurf(X2,Y2,V2, linewidth=0.2);
# ax.plot_trisurf(X3,Y3,V3, linewidth=0.2);
# ax.plot_trisurf(X4,Y4,V4, linewidth=0.2);
ax.plot_trisurf(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X2,Y2,V2, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X14,Y14,V14, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);

ax.set_xlabel("x_axis", fontsize=14)
ax.set_ylabel("y_axis", fontsize=14)
ax.set_zlabel("Particle_volume_fraction", fontsize=14)
ax.set_title("3D_view")

plt.tight_layout()
plt.savefig("3D_2.png")
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
x1, y1, z1,vol_frac1 = np.genfromtxt(inputFile1,usecols=(1,2,3,14),unpack=True)
x2, y2, z2,vol_frac2 = np.genfromtxt(inputFile2,usecols=(1,2,3,14),unpack=True)
x3, y3, z3,vol_frac3 = np.genfromtxt(inputFile3,usecols=(1,2,3,14),unpack=True)
x4, y4, z4,vol_frac4 = np.genfromtxt(inputFile4,usecols=(1,2,3,14),unpack=True)
x5, y5, z5,vol_frac5 = np.genfromtxt(inputFile5,usecols=(1,2,3,14),unpack=True)
x6, y6, z6,vol_frac6 = np.genfromtxt(inputFile6,usecols=(1,2,3,14),unpack=True)
x7, y7, z7,vol_frac7 = np.genfromtxt(inputFile7,usecols=(1,2,3,14),unpack=True)
x8, y8, z8,vol_frac8 = np.genfromtxt(inputFile8,usecols=(1,2,3,14),unpack=True)
x9, y9, z9,vol_frac9 = np.genfromtxt(inputFile9,usecols=(1,2,3,14),unpack=True)
x10, y10, z10,vol_frac10 = np.genfromtxt(inputFile10,usecols=(1,2,3,14),unpack=True)
x11, y11, z11,vol_frac11 = np.genfromtxt(inputFile11,usecols=(1,2,3,14),unpack=True)
x12, y12, z12,vol_frac12 = np.genfromtxt(inputFile12,usecols=(1,2,3,14),unpack=True)
x13, y13, z13,vol_frac13 = np.genfromtxt(inputFile13,usecols=(1,2,3,14),unpack=True)
x14, y14, z14,vol_frac14 = np.genfromtxt(inputFile14,usecols=(1,2,3,14),unpack=True)
x15, y15, z15,vol_frac15 = np.genfromtxt(inputFile15,usecols=(1,2,3,14),unpack=True)
x16, y16, z16,vol_frac16 = np.genfromtxt(inputFile16,usecols=(1,2,3,14),unpack=True)
x17, y17, z17,vol_frac17 = np.genfromtxt(inputFile17,usecols=(1,2,3,14),unpack=True)
x18, y18, z18,vol_frac18 = np.genfromtxt(inputFile18,usecols=(1,2,3,14),unpack=True)
x19, y19, z19,vol_frac19 = np.genfromtxt(inputFile19,usecols=(1,2,3,14),unpack=True)


location1 = (z1 == 20)
location2 = (z2 == 20)
location3 = (z3 == 20)
location4 = (z4 == 20)
location5 = (z5 == 20)
location6 = (z6 == 20)
location7 = (z7 == 20)
location8 = (z8 == 20)
location9 = (z9 == 20)
location10 = (z10 == 20)
location11 = (z11 == 20)
location12 = (z12 == 20)
location13 = (z13 == 20)
location14 = (z14 == 20)
location15 = (z15 == 20)
location16 = (z16 == 20)
location17 = (z17 == 20)

X1 = x1[location1]
Y1 = y1[location1]
V1 = vol_frac1[location1]

X2 = x2[location2]
Y2 = y2[location2]
V2 = vol_frac2[location2]

X3 = x3[location3]
Y3 = y3[location3]
V3 = vol_frac3[location3]

X4 = x4[location4]
Y4 = y4[location4]
V4 = vol_frac4[location4]

X5 = x5[location5]
Y5 = y5[location5]
V5 = vol_frac5[location5]

X6 = x6[location6]
Y6 = y6[location6]
V6 = vol_frac6[location6]

X7 = x7[location7]
Y7 = y7[location7]
V7 = vol_frac7[location7]

X8 = x8[location8]
Y8 = y8[location8]
V8 = vol_frac8[location8]

X9 = x9[location9]
Y9 = y9[location9]
V9 = vol_frac9[location9]

X10 = x10[location10]
Y10 = y10[location10]
V10 = vol_frac10[location10]

X11 = x11[location11]
Y11 = y11[location11]
V11 = vol_frac11[location11]

X12 = x12[location12]
Y12 = y12[location12]
V12 = vol_frac12[location12]

X13 = x13[location13]
Y13 = y13[location13]
V13 = vol_frac13[location13]

X14 = x14[location14]
Y14 = y14[location14]
V14 = vol_frac14[location14]

X15 = x15[location15]
Y15 = y15[location15]
V15 = vol_frac15[location15]

X16 = x16[location16]
Y16 = y16[location16]
V16 = vol_frac16[location16]

X17 = x17[location17]
Y17 = y17[location17]
V17 = vol_frac17[location17]


X_average = (X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10 + X11 + X12 + X13 + X14 + X15 + X16 + X17)/17
Y_average = (Y1 + Y2 + Y3 + Y4 + Y5 + Y6 + Y7 + Y8 + Y9 + Y10 + Y11 + Y12 + Y13 + Y14 + Y15 + Y16 + Y17)/17
V_average = (V1 + V2 + V3 + V4 + V5 + V6 + V7 + V8 + V9 + V10 + V11 + V12 + V13 + V14 + V15 + V16 + V17)/17

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d  

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

# ax.plot_trisurf(X1,Y1,V1, linewidth=0.2);
# ax.scatter(X_average,Y_average,V_average,cmap=plt.cm.viridis);

# ax.plot_trisurf(X1,Y1,V1, linewidth=0.2);
# ax.plot_trisurf(X2,Y2,V2, linewidth=0.2);
# ax.plot_trisurf(X3,Y3,V3, linewidth=0.2);
# ax.plot_trisurf(X4,Y4,V4, linewidth=0.2);
ax.plot_trisurf(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X2,Y2,V2, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X14,Y14,V14, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);

ax.set_xlabel("x_axis", fontsize=14)
ax.set_ylabel("y_axis", fontsize=14)
ax.set_zlabel("Particle_volume_fraction", fontsize=14)
ax.set_title("3D_view")

plt.tight_layout()
plt.savefig("3D_3.png")
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
x1, y1, z1,vol_frac1 = np.genfromtxt(inputFile1,usecols=(1,2,3,14),unpack=True)
x2, y2, z2,vol_frac2 = np.genfromtxt(inputFile2,usecols=(1,2,3,14),unpack=True)
x3, y3, z3,vol_frac3 = np.genfromtxt(inputFile3,usecols=(1,2,3,14),unpack=True)
x4, y4, z4,vol_frac4 = np.genfromtxt(inputFile4,usecols=(1,2,3,14),unpack=True)
x5, y5, z5,vol_frac5 = np.genfromtxt(inputFile5,usecols=(1,2,3,14),unpack=True)
x6, y6, z6,vol_frac6 = np.genfromtxt(inputFile6,usecols=(1,2,3,14),unpack=True)
x7, y7, z7,vol_frac7 = np.genfromtxt(inputFile7,usecols=(1,2,3,14),unpack=True)
x8, y8, z8,vol_frac8 = np.genfromtxt(inputFile8,usecols=(1,2,3,14),unpack=True)
x9, y9, z9,vol_frac9 = np.genfromtxt(inputFile9,usecols=(1,2,3,14),unpack=True)
x10, y10, z10,vol_frac10 = np.genfromtxt(inputFile10,usecols=(1,2,3,14),unpack=True)
x11, y11, z11,vol_frac11 = np.genfromtxt(inputFile11,usecols=(1,2,3,14),unpack=True)
x12, y12, z12,vol_frac12 = np.genfromtxt(inputFile12,usecols=(1,2,3,14),unpack=True)
x13, y13, z13,vol_frac13 = np.genfromtxt(inputFile13,usecols=(1,2,3,14),unpack=True)
x14, y14, z14,vol_frac14 = np.genfromtxt(inputFile14,usecols=(1,2,3,14),unpack=True)
x15, y15, z15,vol_frac15 = np.genfromtxt(inputFile15,usecols=(1,2,3,14),unpack=True)
x16, y16, z16,vol_frac16 = np.genfromtxt(inputFile16,usecols=(1,2,3,14),unpack=True)
x17, y17, z17,vol_frac17 = np.genfromtxt(inputFile17,usecols=(1,2,3,14),unpack=True)
x18, y18, z18,vol_frac18 = np.genfromtxt(inputFile18,usecols=(1,2,3,14),unpack=True)
x19, y19, z19,vol_frac19 = np.genfromtxt(inputFile19,usecols=(1,2,3,14),unpack=True)


location1 = (z1 == 160)
location2 = (z2 == 160)
location3 = (z3 == 160)
location4 = (z4 == 160)
location5 = (z5 == 160)
location6 = (z6 == 160)
location7 = (z7 == 160)
location8 = (z8 == 160)
location9 = (z9 == 160)
location10 = (z10 == 160)
location11 = (z11 == 160)
location12 = (z12 == 160)
location13 = (z13 == 160)
location14 = (z14 == 160)
location15 = (z15 == 160)
location16 = (z16 == 160)
location17 = (z17 == 160)

X1 = x1[location1]
Y1 = y1[location1]
V1 = vol_frac1[location1]

X2 = x2[location2]
Y2 = y2[location2]
V2 = vol_frac2[location2]

X3 = x3[location3]
Y3 = y3[location3]
V3 = vol_frac3[location3]

X4 = x4[location4]
Y4 = y4[location4]
V4 = vol_frac4[location4]

X5 = x5[location5]
Y5 = y5[location5]
V5 = vol_frac5[location5]

X6 = x6[location6]
Y6 = y6[location6]
V6 = vol_frac6[location6]

X7 = x7[location7]
Y7 = y7[location7]
V7 = vol_frac7[location7]

X8 = x8[location8]
Y8 = y8[location8]
V8 = vol_frac8[location8]

X9 = x9[location9]
Y9 = y9[location9]
V9 = vol_frac9[location9]

X10 = x10[location10]
Y10 = y10[location10]
V10 = vol_frac10[location10]

X11 = x11[location11]
Y11 = y11[location11]
V11 = vol_frac11[location11]

X12 = x12[location12]
Y12 = y12[location12]
V12 = vol_frac12[location12]

X13 = x13[location13]
Y13 = y13[location13]
V13 = vol_frac13[location13]

X14 = x14[location14]
Y14 = y14[location14]
V14 = vol_frac14[location14]

X15 = x15[location15]
Y15 = y15[location15]
V15 = vol_frac15[location15]

X16 = x16[location16]
Y16 = y16[location16]
V16 = vol_frac16[location16]

X17 = x17[location17]
Y17 = y17[location17]
V17 = vol_frac17[location17]


X_average = (X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10 + X11 + X12 + X13 + X14 + X15 + X16 + X17)/17
Y_average = (Y1 + Y2 + Y3 + Y4 + Y5 + Y6 + Y7 + Y8 + Y9 + Y10 + Y11 + Y12 + Y13 + Y14 + Y15 + Y16 + Y17)/17
V_average = (V1 + V2 + V3 + V4 + V5 + V6 + V7 + V8 + V9 + V10 + V11 + V12 + V13 + V14 + V15 + V16 + V17)/17

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d  

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

# ax.plot_trisurf(X1,Y1,V1, linewidth=0.2);
# ax.scatter(X_average,Y_average,V_average,cmap=plt.cm.viridis);

# ax.plot_trisurf(X1,Y1,V1, linewidth=0.2);
# ax.plot_trisurf(X2,Y2,V2, linewidth=0.2);
# ax.plot_trisurf(X3,Y3,V3, linewidth=0.2);
# ax.plot_trisurf(X4,Y4,V4, linewidth=0.2);
ax.plot_trisurf(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X2,Y2,V2, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X14,Y14,V14, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);

ax.set_xlabel("x_axis", fontsize=14)
ax.set_ylabel("y_axis", fontsize=14)
ax.set_zlabel("Particle_volume_fraction", fontsize=14)
ax.set_title("3D_view")

plt.tight_layout()
plt.savefig("3D_4.png")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1c568aa32d69> in <module>
#      14 # ax.plot_trisurf(X3,Y3,V3, linewidth=0.2);
#      15 # ax.plot_trisurf(X4,Y4,V4, linewidth=0.2);
# ---> 16 ax.plot_trisurf(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
#      17 # ax.scatter(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
#      18 # ax.scatter(X2,Y2,V2, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
#
# NameError: name 'X_average' is not defined
