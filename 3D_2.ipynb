# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import os
import subprocess
import pandas as pd
import csv
from xlrd import open_workbook
from collections import namedtuple
from pprint import pprint
import statistics
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#### Read data columns from the Raw Particle Data file
inputFile1 = "cells_Gmv.00400.vars"
inputFile2 = "cells_Gmv.00450.vars"
inputFile3 = "cells_Gmv.00500.vars"
inputFile4 = "cells_Gmv.00550.vars"
inputFile5 = "cells_Gmv.00600.vars"
inputFile6 = "cells_Gmv.00650.vars"
inputFile7 = "cells_Gmv.00700.vars"
inputFile8 = "cells_Gmv.00750.vars"
inputFile9 = "cells_Gmv.00800.vars"
inputFile10 = "cells_Gmv.00850.vars"
inputFile11= "cells_Gmv.00900.vars"
inputFile12 = "cells_Gmv.00950.vars"
inputFile13 = "cells_Gmv.01000.vars"

x1, y1, z1,vol_frac1 = np.genfromtxt(inputFile1,usecols=(1,2,3,5),unpack=True)
x2, y2, z2,vol_frac2 = np.genfromtxt(inputFile2,usecols=(1,2,3,5),unpack=True)
x3, y3, z3,vol_frac3 = np.genfromtxt(inputFile3,usecols=(1,2,3,5),unpack=True)
x4, y4, z4,vol_frac4 = np.genfromtxt(inputFile4,usecols=(1,2,3,5),unpack=True)
x5, y5, z5,vol_frac5 = np.genfromtxt(inputFile5,usecols=(1,2,3,5),unpack=True)
x6, y6, z6,vol_frac6 = np.genfromtxt(inputFile6,usecols=(1,2,3,5),unpack=True)
x7, y7, z7,vol_frac7 = np.genfromtxt(inputFile7,usecols=(1,2,3,5),unpack=True)
x8, y8, z8,vol_frac8 = np.genfromtxt(inputFile8,usecols=(1,2,3,5),unpack=True)
x9, y9, z9,vol_frac9 = np.genfromtxt(inputFile9,usecols=(1,2,3,5),unpack=True)
x10, y10, z10,vol_frac10 = np.genfromtxt(inputFile10,usecols=(1,2,3,5),unpack=True)
x11, y11, z11,vol_frac11 = np.genfromtxt(inputFile11,usecols=(1,2,3,5),unpack=True)
x12, y12, z12,vol_frac12 = np.genfromtxt(inputFile12,usecols=(1,2,3,5),unpack=True)
x13, y13, z13,vol_frac13 = np.genfromtxt(inputFile13,usecols=(1,2,3,5),unpack=True)

# %%
location1 = (z1 == 150)
location2 = (z2 == 150)
location3 = (z3 == 150)
location4 = (z4 == 150)
location5 = (z5 == 150)
location6 = (z6 == 150)
location7 = (z7 == 150)
location8 = (z8 == 150)
location9 = (z9 == 150)
location10 = (z10 == 150)
location11 = (z11 == 150)
location12 = (z12 == 150)
location13 = (z13 == 150)

X1 = x1[location1]
Y1 = y1[location1]
V1 = vol_frac1[location1]

X2 = x2[location2]
Y2 = y2[location2]
V2 = vol_frac2[location2]

X3 = x3[location3]
Y3 = y3[location3]
V3 = vol_frac3[location3]

X4 = x4[location4]
Y4 = y4[location4]
V4 = vol_frac4[location4]

X5 = x5[location5]
Y5 = y5[location5]
V5 = vol_frac5[location5]

X6 = x6[location6]
Y6 = y6[location6]
V6 = vol_frac6[location6]

X7 = x7[location7]
Y7 = y7[location7]
V7 = vol_frac7[location7]

X8 = x8[location8]
Y8 = y8[location8]
V8 = vol_frac8[location8]

X9 = x9[location9]
Y9 = y9[location9]
V9 = vol_frac9[location9]

X10 = x10[location10]
Y10 = y10[location10]
V10 = vol_frac10[location10]

X11 = x11[location11]
Y11 = y11[location11]
V11 = vol_frac11[location11]

X12 = x12[location12]
Y12 = y12[location12]
V12 = vol_frac12[location12]

X13 = x13[location13]
Y13 = y13[location13]
V13 = vol_frac13[location13]

# %%
X_average = (X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10 + X11 + X12 + X13)/13
Y_average = (Y1 + Y2 + Y3 + Y4 + Y5 + Y6 + Y7 + Y8 + Y9 + Y10 + Y11 + Y12 + Y13)/13
V_average = (V1 + V2 + V3 + V4 + V5 + V6 + V7 + V8 + V9 + V10 + V11 + V12 + V13)/13

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d  

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')

# ax.plot_trisurf(X1,Y1,V1, linewidth=0.2);
# ax.scatter(X_average,Y_average,V_average,cmap=plt.cm.viridis);

# ax.plot_trisurf(X1,Y1,V1, linewidth=0.2);
# ax.plot_trisurf(X2,Y2,V2, linewidth=0.2);
# ax.plot_trisurf(X3,Y3,V3, linewidth=0.2);
# ax.plot_trisurf(X4,Y4,V4, linewidth=0.2);
ax.plot_trisurf(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);
# ax.scatter(X_average,Y_average,V_average, cmap=plt.cm.viridis, linewidth=0.2, alpha=1);


ax.set_xlabel("x_axis", fontsize=14)
ax.set_ylabel("y_axis", fontsize=14)
ax.set_zlabel("Particle_volume_fraction", fontsize=14)
ax.set_title("3D_view")

plt.tight_layout()
plt.savefig("3D.png")
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
import seaborn as sns
sns.set_style('white')
fig, ax = plt.subplots(figsize=(8,6))


sns.distplot(V1, hist=False, bins=10)
sns.distplot(V2, hist=False, bins=10)
sns.distplot(V3, hist=False, bins=10)
sns.distplot(V4, hist=False, bins=10)
sns.distplot(V5, hist=False, bins=10)
sns.distplot(V6, hist=False, bins=10)
sns.distplot(V7, hist=False, bins=10)
sns.distplot(V8, hist=False, bins=10)
sns.distplot(V9, hist=False, bins=10)
sns.distplot(V10, hist=False, bins=10)
sns.distplot(V11, hist=False, bins=10)
sns.distplot(V12, hist=False, bins=10)
sns.distplot(V13, hist=False, bins=10)

plt.xlabel('Particle volfraction', fontsize=16)
plt.ylabel('Percentage, %', fontsize=16)
# Out:
# Text(0, 0.5, 'Percentage, %')

# %%
import seaborn as sns
sns.set_style('white')
fig, ax = plt.subplots(figsize=(8,6))


sns.distplot(np.log(V1), hist=False, bins=10)
sns.distplot(np.log(V2), hist=False, bins=10)
sns.distplot(np.log(V3), hist=False, bins=10)
sns.distplot(np.log(V4), hist=False, bins=10)
sns.distplot(np.log(V5), hist=False, bins=10)
sns.distplot(np.log(V6), hist=False, bins=10)
sns.distplot(np.log(V7), hist=False, bins=10)
sns.distplot(np.log(V8), hist=False, bins=10)
sns.distplot(np.log(V9), hist=False, bins=10)
sns.distplot(np.log(V10), hist=False, bins=10)
sns.distplot(np.log(V11), hist=False, bins=10)
sns.distplot(np.log(V12), hist=False, bins=10)
sns.distplot(np.log(V13), hist=False, bins=10)

plt.xlabel('Particle volfraction', fontsize=16)
plt.ylabel('Percentage, %', fontsize=16)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:110: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     453     try:
# --> 454         bw = float(bw)
#     455     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-ca39f436ad59> in <module>
#       4
#       5
# ----> 6 sns.distplot(np.log(V1), hist=False, bins=10)
#       7 sns.distplot(np.log(V2), hist=False, bins=10)
#       8 sns.distplot(np.log(V3), hist=False, bins=10)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     281         x, y = _statsmodels_univariate_kde(data, kernel, bw,
#     282                                            gridsize, cut, clip,
# --> 283                                            cumulative=cumulative)
#     284     else:
#     285         # Fall back to scipy if missing statsmodels
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in _statsmodels_univariate_kde(data, kernel, bw, gridsize, cut, clip, cumulative)
#     353     fft = kernel == "gau"
#     354     kde = smnp.KDEUnivariate(data)
# --> 355     kde.fit(kernel, bw, fft, gridsize=gridsize, cut=cut, clip=clip)
#     356     if cumulative:
#     357         grid, y = kde.support, kde.cdf
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in fit(self, kernel, bw, fft, weights, gridsize, adjust, cut, clip)
#     140             density, grid, bw = kdensityfft(endog, kernel=kernel, bw=bw,
#     141                     adjust=adjust, weights=weights, gridsize=gridsize,
# --> 142                     clip=clip, cut=cut)
#     143         else:
#     144             density, grid, bw = kdensity(endog, kernel=kernel, bw=bw,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     454         bw = float(bw)
#     455     except:
# --> 456         bw = bandwidths.select_bandwidth(X, bw, kern) # will cross-val fit this pattern?
#     457     bw *= adjust
#     458
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py in select_bandwidth(x, bw, kernel)
#     170 #TODO: uncomment checks when we have non-rule of thumb bandwidths for diff. kernels
#     171 #    if kernel == "gauss":
# --> 172     return bandwidth_funcs[bw](x, kernel)
#     173 #    else:
#     174 #        raise ValueError("Only Gaussian Kernels are currently supported")
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\bandwidths.py in bw_scott(x, kernel)
#      53     A = _select_sigma(x)
#      54     n = len(x)
# ---> 55     return 1.059 * A * n ** (-0.2)
#      56
#      57 def bw_silverman(x, kernel=None):
#
# ZeroDivisionError: 0.0 cannot be raised to a negative power

# %%
print((np.std(V_average)))
print((np.mean(V_average)))
# Out:
# 1.8679463765409046e-05
# 1.3134680914708374e-05

# %%
volume = []

for v in V1:
    volume.append(v)
    
for v in V2:
    volume.append(v)
    
for v in V3:
    volume.append(v)
    
for v in V4:
    volume.append(v)
    
for v in V5:
    volume.append(v)
    
for v in V6:
    volume.append(v)
    
for v in V7:
    volume.append(v)
    
for v in V8:
    volume.append(v)
    
for v in V9:
    volume.append(v)
    
for v in V10:
    volume.append(v)
    
for v in V11:
    volume.append(v)
    
for v in V12:
    volume.append(v)

for v in V13:
    volume.append(v)

# %%
volume_half_std = []

for v in volume:
    if 2.245e-05>v>0.375e-05:
        volume_half_std.append(v)

# %%
volume_1_std = []

for v in volume:
    if 3.18e-05>v>-0.56e-05:
        volume_1_std.append(v)

# %%
volume_2_std = []

for v in volume:
    if 5.05e-05>v>-2.43e-05:
        volume_2_std.append(v)

# %%
percentage_1 = len(volume_half_std)/len(volume)
percentage_2 = len(volume_1_std)/len(volume)
percentage_3 = len(volume_2_std)/len(volume)
print(percentage_1)
print(percentage_2)
print(percentage_3)
# Out:
# 0.046474358974358976
# 0.9471153846153846
# 0.9519230769230769

# %%
x = np.arange(3)
y = [0.046,0.95, 0.95]

fig, ax = plt.subplots(figsize=(6,6))
plt.bar(x, y, width = 0.5)
plt.xticks(x, ('Half_std', 'One_std', 'Two_std'), fontsize=16)
plt.ylabel('Frequency within the std', fontsize=16)

plt.show()
plt.savefig("histogram2.png")
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# #
